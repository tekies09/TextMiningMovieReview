# %%
import pandas as pd
csv_data = pd.read_csv("2016to2018Movie.csv",encoding='euc-kr')

# %%
def findNumber(MovieName) :
    from bs4 import BeautifulSoup
    from selenium import webdriver
    from selenium.webdriver.common.keys import Keys
    search_keyword=MovieName
    MovieInput = driver.find_elements_by_name('query')
    MovieInput[1].send_keys(search_keyword)
    MovieInput[1].send_keys(Keys.ENTER)
    soup =BeautifulSoup(driver.page_source)
    Movieul = soup.find('ul',class_='search_list_1')
    if(Movieul==None):
        return 0
    MovieLink = Movieul.find('a')
    if(MovieLink==None):
        return 0
    equal=MovieLink['href'].find("=")
    number = MovieLink['href'][equal+1:]
    return number

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
url="https://movie.naver.com/"
driver=webdriver.Chrome('chromedriver')
driver.get(url)
list_movie=csv_data["영화명"]
dic = {'MovieName':'Number'}
k=" "
for i in list_movie:
    k=findNumber(i)
    dic[i]=k
print(dic)
# Out:
# {'MovieName': 'Number', '신과함께-인과 연': '167697', '어벤져스: 인피니티 워': '136315', '보헤미안 랩소디': '156464', '미션 임파서블: 폴아웃': '154222', '신과함께-죄와 벌': '85579', '쥬라기 월드: 폴른 킹덤': '154285', '앤트맨과 와스프': '144330', '안시성': '163533', '블랙 팬서': '137326', '완벽한 타인': '167638', '1987': '158191', '독전': '158178', '공작': '153687', '베놈': '119428', '암수살인': '167105', '데드풀 2': '149236', '국가부도의 날': '164192', '코코': '151728', '아쿠아맨': '151153', '그것만이 내 세상': '158180', '마녀': '175322', '탐정: 리턴즈': '159892', '인크레더블 2': '136990', '서치': '172425', '너의 결혼식': '140652', '곤지암': '172454', '지금 만나러 갑니다': '168298', '목격자': '169015', '조선명탐정: 흡혈괴마의 비밀': '165748', '신비한 동물들과 그린델왈드의 범죄': '154255', '메이즈 러너: 데스 큐어': '149248', '맘마미아!2': '164115', '레디 플레이어 원': '136898', '명당': '162981', '협상': '164106', '마약왕': '157297', '쥬만지: 새로운 세계': '152656', '창궐': '160487', '성난황소': '174835', '도어락': '171755', '리틀 포레스트': '154449', '골든슬럼버': '158112', '램페이지': '162249', '궁합': '141206', '오션스8': '153675', '사라진 밤': '165026', '스윙키즈': '164101', '바람 바람 바람': '142739', 'PMC: 더 벙커
# ...

# %%
dataframe =pd.DataFrame(dic.items(), columns=['MovieName', 'Number'])
dataframe.to_csv("movieNumber.csv",encoding='euc-kr',header=False,index=False)

# %%
print(dic)
# Out:
# {'MovieName': 'Number', '신과함께-인과 연': '167697', '어벤져스: 인피니티 워': '136315', '보헤미안 랩소디': '156464', '미션 임파서블: 폴아웃': '154222', '신과함께-죄와 벌': '85579', '쥬라기 월드: 폴른 킹덤': '154285', '앤트맨과 와스프': '144330', '안시성': '163533', '블랙 팬서': '137326', '완벽한 타인': '167638', '1987': '158191', '독전': '158178', '공작': '153687', '베놈': '119428', '암수살인': '167105', '데드풀 2': '149236', '국가부도의 날': '164192', '코코': '151728', '아쿠아맨': '151153', '그것만이 내 세상': '158180', '마녀': '175322', '탐정: 리턴즈': '159892', '인크레더블 2': '136990', '서치': '172425', '너의 결혼식': '140652', '곤지암': '172454', '지금 만나러 갑니다': '168298', '목격자': '169015', '조선명탐정: 흡혈괴마의 비밀': '165748', '신비한 동물들과 그린델왈드의 범죄': '154255', '메이즈 러너: 데스 큐어': '149248', '맘마미아!2': '164115', '레디 플레이어 원': '136898', '명당': '162981', '협상': '164106', '마약왕': '157297', '쥬만지: 새로운 세계': '152656', '창궐': '160487', '성난황소': '174835', '도어락': '171755', '리틀 포레스트': '154449', '골든슬럼버': '158112', '램페이지': '162249', '궁합': '141206', '오션스8': '153675', '사라진 밤': '165026', '스윙키즈': '164101', '바람 바람 바람': '142739', 'PMC: 더 벙커
# ...

# %%
import pandas as pd
from pandas import DataFrame as df
listk=[1,2]
df1=df(data={'rev':listk})
print(listk)
print(df1)
dataframe =pd.DataFrame(listk)
dataframe.to_csv

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
url="https://movie.naver.com/"
driver=webdriver.Chrome('chromedriver')
driver.get(url)
MovieName = driver.find_elements_by_name('query')
MovieName[1].send_keys('BIFAN2018 - 판타스틱 단편 걸작선 3')
MovieName[1].send_keys(Keys.ENTER)
k = soup.find('ul',class_='search_list_1')
l = k.find('a')
print(l)
# Out:
# <a href="/movie/bi/mi/basic.nhn?code=167613"><img alt="" height="95" src="https://movie-phinf.pstatic.net/20190906_128/1567761736426S6Fje_JPEG/movie_image.jpg?type=f67" width="67"/></a>

# %%
equal=MovieLink['href'].find("=")
number = MovieLink['href'][equal+1:]
# Out:
# 167613

# %%
def findNumber(MovieName) :
    from bs4 import BeautifulSoup
    from selenium import webdriver
    from selenium.webdriver.common.keys import Keys
    search_keyword=MovieName
    MovieInput = driver.find_elements_by_name('query')
    MovieInput[1].send_keys(search_keyword)
    MovieInput[1].send_keys(Keys.ENTER)
    soup =BeautifulSoup(driver.page_source)
    Movieul = soup.find('ul',class_='search_list_1')
    if(Movieul==None):
        return 0
    MovieLink = Movieul.find('a')
    if(MovieLink==None):
        return 0
    equal=MovieLink['href'].find("=")
    number = MovieLink['href'][equal+1:]
    return number
